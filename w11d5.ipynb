# %% [markdown]
# ESERCIZIO 01

# %%
import pandas as pd
df=pd.read_csv("Mappa-dei-pub-circoli-locali-in-italia.csv", encoding="latin1", sep=";")

# %% [markdown]
# • quanti dati ci sono in totale?

# %%
df.shape
print ("righe*colonne",df.shape)
# Out:
# righe*colonne (2635, 9)

# %%
print("Numero di righe:", len(df))
# Out:
# Numero di righe: 2635

# %% [markdown]
# • quali sono i metadati?

# %%
print(list(df.columns))
# Out:
# ['Comune', 'Provincia', 'Regione', 'Nome', 'Anno inserimento', 'Data e ora inserimento', 'Identificatore in OpenStreetMap', 'Longitudine', 'Latitudine']

# %% [markdown]
# • stampiamo il primo elemento

# %%
df.head(1)
# Out:
#   Comune Provincia Regione Nome  Anno inserimento Data e ora inserimento  \
# 0  ALTRO     ALTRO   ALTRO  NaN              2011   2011-06-25T23:17:43Z
#
#    Identificatore in OpenStreetMap  Longitudine  Latitudine
# 0                       1339088150    13.733257    45.57583

# %% [markdown]
# • stampiamo l'ultimo elemento

# %%
df.tail(1)
# Out:
#      Comune              Provincia Regione          Nome  Anno inserimento  \
# 2634  TRANI  BARLETTA-ANDRIA-TRANI  Puglia  Well's Fargo              2009
#
#      Data e ora inserimento  Identificatore in OpenStreetMap  Longitudine  \
# 2634   2009-08-10T12:44:03Z                        387223648    16.436765
#
#       Latitudine
# 2634   41.267264

# %%
df.groupby(['Comune','Provincia','Regione']).first()
# Out:
#                                                                                          Nome  \
# Comune                Provincia                      Regione
# ABBADIA SAN SALVATORE SIENA                          Toscana                        Baby Ball
# ABBIATEGRASSO         CITTA' METROPOLITANA DI MILANO Lombardia                          Big 4
# ABETONE               PISTOIA                        Toscana                             Grog
# ACQUAPENDENTE         VITERBO                        Lazio                       Franco Marlo
# AGEROLA               CITTA' METROPOLITANA DI NAPOLI Campania                          Pub 18
# ...                                                                                       ...
# VITERBO               VITERBO                        Lazio                           Andrew's
# VO                    PADOVA                         Veneto                 The Beer Brothers
# ...

# %%
df.groupby(['Comune','Provincia','Regione']).last(5)
# Out:
#                                                                             Anno inserimento  \
# Comune                Provincia                      Regione
# ABBADIA SAN SALVATORE SIENA                          Toscana                            2010
# ABBIATEGRASSO         CITTA' METROPOLITANA DI MILANO Lombardia                          2009
# ABETONE               PISTOIA                        Toscana                            2014
# ACQUAPENDENTE         VITERBO                        Lazio                              2012
# AGEROLA               CITTA' METROPOLITANA DI NAPOLI Campania                           2013
# ...                                                                                      ...
# VITERBO               VITERBO                        Lazio                              2012
# VO                    PADOVA                         Veneto                             2013
# ...

# %% [markdown]
# •riusciamo a stampare un elemento a caso?

# %%
df.sample(1)
# Out:
#          Comune      Provincia         Regione        Nome  Anno inserimento  \
# 1415  SCANDIANO  REGGIO EMILIA  Emilia-Romagna  Robin Hood              2014
#
#      Data e ora inserimento  Identificatore in OpenStreetMap  Longitudine  \
# 1415   2014-07-11T15:12:05Z                       2579801153    10.722846
#
#       Latitudine
# 1415   44.619441

# %% [markdown]
# • quali sono gli anni di inserimento presenti?

# %%
df.groupby('Anno inserimento').size()
# Out:
# Anno inserimento
# 2007      1
# 2008     50
# 2009    115
# 2010    191
# 2011    256
# 2012    467
# 2013    433
# 2014    490
# 2015    563
# 2016     69
# dtype: int64

# %% [markdown]
# quante attività ci sono nel quadrato di longitudine 9-10 e latitudine 45-46?

# %%
filtro_coordinate = df[(df['Longitudine'] >= 9) & (df['Longitudine'] <= 10) & 
                 (df['Latitudine'] >= 45) & (df['Latitudine'] <= 46)]

# %%
Numero_attività = filtro_coordinate.groupby(['Regione', 'Provincia']).size()

# %%
print(Numero_attività)
# Out:
# Regione         Provincia
# ALTRO           ALTRO                               1
# Emilia-Romagna  PIACENZA                            3
# Lombardia       BERGAMO                            32
#                 BRESCIA                             9
#                 CITTA' METROPOLITANA DI MILANO    156
#                 COMO                               21
#                 CREMONA                            18
#                 LECCO                               6
#                 LODI                                5
#                 MONZA-BRIANZA                      44
#                 PAVIA                               7
#                 VARESE                              4
# dtype: int64

# %%
print("Numero di attività per Provincia e Regione:")

for (provincia, regione), count in Numero_attività.items():
    print(f"- {provincia}, {regione}: {count} attività")
# Out:
# Numero di attività per Provincia e Regione:
# - ALTRO, ALTRO: 1 attività
# - Emilia-Romagna, PIACENZA: 3 attività
# - Lombardia, BERGAMO: 32 attività
# - Lombardia, BRESCIA: 9 attività
# - Lombardia, CITTA' METROPOLITANA DI MILANO: 156 attività
# - Lombardia, COMO: 21 attività
# - Lombardia, CREMONA: 18 attività
# - Lombardia, LECCO: 6 attività
# - Lombardia, LODI: 5 attività
# - Lombardia, MONZA-BRIANZA: 44 attività
# - Lombardia, PAVIA: 7 attività
# - Lombardia, VARESE: 4 attività

# %% [markdown]
# •quante attività ci sono nella provincia di Vicenza?

# %%
Vicenza = df[df['Provincia'] == 'VICENZA']
Numero_attivita_comune = Vicenza.groupby('Provincia').size()
print(Numero_attivita_comune)
# Out:
# Provincia
# VICENZA    73
# dtype: int64

# %% [markdown]
# • quante enoteche ci sono, e come si chiamano?

# %% [markdown]
# • quante attività ci sono nel Lazio & Abruzzo

# %%
Lazio_Abruzzo = df[(df['Regione'] == 'Lazio') | (df['Regione'] == 'Abruzzo') ]

# %%
Numero_attività = Lazio_Abruzzo.groupby(['Regione', 'Provincia']).size()

# %%
print(Numero_attività)
# Out:
# Regione  Provincia
# Abruzzo  CHIETI                                     7
#          L'AQUILA                                  10
#          PESCARA                                   17
#          TERAMO                                    14
# Lazio    CITTA' METROPOLITANA DI ROMA CAPITALE    230
#          FROSINONE                                  7
#          LATINA                                    30
#          RIETI                                      7
#          VITERBO                                   15
# dtype: int64

# %% [markdown]
# Esercizio 02
# Il dataset insurance.csv dei beginner_datasets contiene dati su caratteristiche e abitudini delle persone rispetto ai costi individuali per le cure mediche come premio per le assicurazioni sulla salute.

# %%
import pandas as pd
df= pd.read_csv('insurance.csv')

# %% [markdown]
# • Visualizziamone le dimensioni, un'anteprima, e osserviamo i nomi di colonna

# %%
df.shape
print ("righe*colonne",df.shape)
# Out:
# righe*colonne (1338, 7)

# %%
print(df)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# • Quali sono le medie di charges rispetto a region? Ci sono differenze significative?

# %%
media_charges_per_region = df.groupby('region')['charges'].mean()
print(media_charges_per_region)
# Out:
# region
# northeast    13406.384516
# northwest    12417.575374
# southeast    14735.411438
# southwest    12346.937377
# Name: charges, dtype: float64

# %% [markdown]
# • E rispetto a smoker? E a sex?

# %%
media_charges_per_smoker = df.groupby('smoker')['charges'].mean()
print(media_charges_per_smoker)
# Out:
# smoker
# no      8434.268298
# yes    32050.231832
# Name: charges, dtype: float64

# %%
media_charges_per_sex = df.groupby('sex')['charges'].mean()
print(media_charges_per_sex)
# Out:
# sex
# female    12569.578844
# male      13956.751178
# Name: charges, dtype: float64

# %% [markdown]
# • Quali sono i descrittori statistici di bmi? Quali sono minimo, media e massimo di charges rispetto ai diversi quartili dei valori di bmi?

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# ESERCIZIO 3
# Carichiamo in un DataFrame il dataset iris.csv dei beginner_datasets e calcoliamo:

# %%
iris = pd.read_csv("Iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# La media della lunghezza dei petali di tutto il dataset

# %%
media_petali = iris['PetalLengthCm'].mean()
print(media_petali)
# Out:
# 3.758666666666666

# %%
media_specie = iris.groupby('Species').PetalLengthCm.mean()

print(media_specie)
# Out:
# Species
# Iris-setosa        1.464
# Iris-versicolor    4.260
# Iris-virginica     5.552
# Name: PetalLengthCm, dtype: float64

# %% [markdown]
# • Media, minimo e massimo della larghezza dei sepali per ogni specie, utilizzando .groupby() e .agg()

# %%
sepali = iris.groupby('Species').SepalWidthCm.agg(['mean', 'min', 'max'])


print(sepali)
# Out:
#                   mean  min  max
# Species
# Iris-setosa      3.418  2.3  4.4
# Iris-versicolor  2.770  2.0  3.4
# Iris-virginica   2.974  2.2  3.8

# %% [markdown]
# ESERCIZIO 04
# Nei beginner_datasets, il dataset wine.csv contiene delle analisi organolettiche su diverse qualità di vini:

# %% [markdown]
# • Visualizziamone le dimensioni, un'anteprima, e osserviamo i nomi di colonna

# %%
wine = pd.read_csv('wine.csv')
wine
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# ...

# %% [markdown]
# • Qual è la media di concentrazione alcolica per ogni qualità? Ci sono differenze? E rispetto alla media totale?

# %%
media_con_alcolica = wine.groupby('Alcohol').Wine.mean()
print(media_con_alcolica)
# Out:
# Alcohol
# 11.03    2.0
# 11.41    2.0
# 11.45    2.0
# 11.46    2.0
# 11.56    2.0
#         ...
# 14.37    1.0
# 14.38    1.0
# 14.39    1.0
# 14.75    1.0
# 14.83    1.0
# Name: Wine, Length: 126, dtype: float64

# %% [markdown]
# ESERCIZIO 05
# Nei beginner_datasets, il file boston.csv contiene il Boston Housing Dataset, che deriva dalle informazioni raccolte dal Census Service
# degli Stati Uniti sulle abitazioni nell'area di Boston. Di seguito vengono descritte le colonne del dataset:

# %%
boston = pd.read_csv('boston.csv')
display(boston)
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# • La media del prezzo delle case cambia a seconda della distanza dal fiume Charles?

# %%
distanza_fiume=boston.groupby('chas').medv.mean()
print(distanza_fiume)
# Out:
# chas
# 0    22.093843
# 1    28.440000
# Name: medv, dtype: float64

# %% [markdown]
# • Si nota una correlazione tra il tasso di criminalità e il valore delle abitazioni? Come si può spiegare il risultato?

# %%
boston.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# • Qual è la media del numero di stanze rispetto al rapporto alunni-insegnanti?
# E del valore delle case? Appare esserci una qualche correlazione? Come si può spiegare il risultato?

# %%
media_rm_per_ptratio = boston.groupby('ptratio')['rm'].mean()

print(media_rm_per_ptratio)
# Out:
# ptratio
# 12.6    7.222667
# 13.0    7.406167
# 13.6    7.923000
# 14.4    7.875000
# 14.7    6.246235
# 14.8    6.752333
# 14.9    7.311250
# 15.1    6.816000
# 15.2    6.421923
# 15.3    6.705333
# 15.5    7.241000
# 15.6    6.702000
# 15.9    6.997000
# 16.0    6.230600
# 16.1    6.428800
# 16.4    6.139667
# 16.6    6.344188
# 16.8    6.146750
# 16.9    6.016400
# 17.0    6.868250
# 17.3    6.383000
# 17.4    7.212333
# 17.6    6.822429
# 17.8    6.496130
# 17.9    6.134818
# 18.0    7.218600
# 18.2    6.283000
# 18.3    6.520500
# 18.4    6.285938
# 18.5    6.288750
# 18.6    6.111588
# 18.7    6.406556
# 18.8    5.956000
# 18.9    5.785667
# 19.0    6.453750
# 19.1    6.234882
# 19.2    6.053632
# 19.6    6.224000
# 19.7    6.303250
# 20.1    5.585400
# 20.2    6.024021
# 20.9    6.266273
# 21.0    6.039778
# 21.1    5.888000
# 21.2    6.028533
# 22.0    5.799500
# Name: rm, dtype: float64

# %%
stanze_valorecase=boston.groupby('medv').rm.mean()
print(stanze_valorecase)
# Out:
# medv
# 5.0     5.5680
# 5.6     5.9870
# 6.3     5.8520
# 7.0     4.9665
# 7.2     6.0180
#          ...
# 46.7    7.6860
# 48.3    8.2470
# 48.5    7.8530
# 48.8    8.3980
# 50.0    7.4840
# Name: rm, Length: 229, dtype: float64

# %% [markdown]
# • Rispetto all'accessibilità alle autostrade, cambia qualcosa la media delle età delle abitazioni? E del numero di stanze? E delle tasse?

# %%
stanze_autostrade=boston.groupby('rad').rm.mean()
print(stanze_autostrade)
# Out:
# rad
# 1     6.555850
# 2     6.649958
# 3     6.473026
# 4     6.133118
# 5     6.393157
# 6     6.104731
# 7     6.647765
# 8     6.950792
# 24    6.022152
# Name: rm, dtype: float64

# %%
media_rm_per_anno = boston.groupby('age')['rm'].mean()


print(media_rm_per_anno)
# Out:
# age
# 2.9      6.77000
# 6.0      6.27300
# 6.2      6.24500
# 6.5      6.21100
# 6.6      6.29300
#           ...
# 98.8     6.41975
# 98.9     5.86500
# 99.1     6.54500
# 99.3     7.39300
# 100.0    5.68393
# Name: rm, Length: 356, dtype: float64

# %%
media_rm_per_tax = boston.groupby('tax')['rm'].mean()


print(media_rm_per_tax)
# Out:
# tax
# 187    6.728000
# 188    5.881286
# 193    6.774375
# 198    7.923000
# 216    7.269800
#          ...
# 432    6.078000
# 437    6.028533
# 469    5.888000
# 666    6.022152
# 711    5.585400
# Name: rm, Length: 66, dtype: float64

# %% [markdown]
# ESERCIZIO 06

# %% [markdown]
# Abbiamo un DataFrame di dipendenti:

# %%
import pandas as pd

# %%
employees_df = pd.DataFrame({
    'employee_id': [101, 102, 103, 104, 105],
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Emma'],
    'department_id': [1, 2, 1, 2, 3]
})

# %% [markdown]
# E un DataFrame di dipartimenti:

# %%
departments_df = pd.DataFrame({
    'department_id': [1, 2, 3],
    'department_name': ['HR', 'IT', 'Finance'],
    'location': ['New York', 'San Francisco', 'Chicago']
})

# %% [markdown]
# • Unire questi DataFrame in base alla colonna comune department_id, in modo da avere nel risultato informazioni sia sui dipendenti che sui dipartimenti, usando la funzione .merge()

# %%
merge_df= pd.merge(employees_df, departments_df, on='department_id', how='inner')
print(merge_df)
# Out:
#    employee_id     name  department_id department_name       location
# 0          101    Alice              1              HR       New York
# 1          102      Bob              2              IT  San Francisco
# 2          103  Charlie              1              HR       New York
# 3          104    David              2              IT  San Francisco
# 4          105     Emma              3         Finance        Chicago

# %% [markdown]
# • Per ogni DataFrame, trasformare la colonna department_id nell'indice, facendo in modo che la modifica sia permanente; poi unire i due dataset mediante il metodo .join()

# %%
employees_df.set_index('department_id', inplace=True)
departments_df.set_index('department_id', inplace=True)

# %%
join_df = employees_df.join(departments_df)

# %%
display(join_df)
# Out:
#                employee_id     name department_name       location
# department_id
# 1                      101    Alice              HR       New York
# 2                      102      Bob              IT  San Francisco
# 1                      103  Charlie              HR       New York
# 2                      104    David              IT  San Francisco
# 3                      105     Emma         Finance        Chicago

# %% [markdown]
# ESERCIZIO 07
# • Dal database AdventureWorksDW importiamo le tabelle dimemployee e dimemployeesalesterritory come DataFrame

# %%
pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os

# %%
import os
import dotenv
import sqlalchemy
import pandas as pd

dotenv.load_dotenv(override=True, dotenv_path=".env.txt")

username = os.getenv("username")
password = os.getenv("password")
host = os.getenv("host")
dbname = os.getenv("dbname")

connection_string = "mysql+pymysql://" + username + ":" + password + "@" + host + "/" + dbname

db_engine = sqlalchemy.create_engine(connection_string)

# %%
query = "SELECT * FROM dimproduct"
df = pd.read_sql(query, db_engine)
